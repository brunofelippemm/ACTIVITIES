# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
from stats import median
import numpy as np
import math

# %%
### Data Points
arr = np.array([2.3, 10.2,11.2, 12.3, 14.5, 14.6, 15.0, 15.1, 19.0, 24.0])
arr
# Out:
# array([ 2.3, 10.2, 11.2, 12.3, 14.5, 14.6, 15. , 15.1, 19. , 24. ])

# %%
# Find the median
arr_median = np.median(arr)
arr_median
# Out:
# 14.55

# %%
# Use numpy to create quartiles
q2_arr = np.quantile(arr, .50) 
q1_arr = np.quantile(arr, .25) 
q3_arr = np.quantile(arr, .75)

# %%
# Print the quartiles
print("Q2 quantile of arr : ", q2_arr) 
print("Q1 quantile of arr : ", q1_arr) 
print("Q3 quantile of arr : ", q3_arr)
# Out:
# Q2 quantile of arr :  14.55
# Q1 quantile of arr :  11.474999999999998
# Q3 quantile of arr :  15.075

# %%
# Calculate the interquartile range
iqr_arr = q3_arr - q1_arr
iqr_arr
# Out:
# 3.6000000000000014

# %%
# Find lower boundary
# Q1 - 1.5 * IQR
lower_bound = q1_arr - 1.5*iqr_arr
lower_bound
# Out:
# 6.074999999999996

# %%
# Find upper boundary
# Q3 + 1.5 * IQR
upper_bound = q3_arr + 1.5*iqr_arr
upper_bound
# Out:
# 20.475

# %%
# Check for any lower outliers
lower_outliers = []
for i in arr:
    if i < lower_bound:
        lower_outliers.append(i)
lower_outliers
# Out:
# [2.3]

# %%
# Check for any upper outliers
upper_outliers = []
for i in arr:
    if i > upper_bound:
        upper_outliers.append(i)
upper_outliers
# Out:
# [24.0]

# %%
# Create box plot
plt.boxplot(arr, autorange=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
